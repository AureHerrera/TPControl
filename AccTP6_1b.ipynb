# %% [markdown]
# <a href="https://colab.research.google.com/github/AureHerrera/TPControl/blob/main/AccTP6_1b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Calculo de un conmutador Flyback

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
# df = pd. read_csv ('TP2-2.csv', encoding='utf-16',sep='\t',header=0)
# # encoding='utf-16',sep='\t',header=0)
# print(df.head(2))
# print(df.tail(2))
# plt.plot(df["time"],df["V(volprobe6)"], 'b' , linewidth =.10)
# plt.plot(df["time"],df["V(volprobe4)"], 'r' , linewidth =.10)
# plt.legend(['V(volprobe6)','V(volprobe4)'])

# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import matplotlib.ticker as ticker
# import math
df = pd. read_csv ('TP6-1b-3ohmID.csv', encoding='utf-16',sep='\t',header=0)
# encoding='utf-16',sep='\t',header=0)
print(df.head(2))
print(df.tail(2))
plt.plot(df["time"],df["V(volprobe7)"], 'b' , linewidth =.50)
plt.plot(df["time"],df["V(volprobe4)"], 'r' , linewidth =.50)
plt.plot(df["time"],(df["V(volprobe4)"]-df["V(volprobe8)"])/0.01, 'g' , linewidth =.50)
plt.legend(['V(volprobe7)','V(volprobe4)','Current'])
# Out:
#            time  V(volprobe7)  V(volprobe8)  V(volprobe4)
# 0  0.000000e+00          0.00  0.000000e+00  0.000000e+00
# 1  1.000000e-12          0.03  1.665966e-10  1.686333e-10
#          time  V(volprobe7)  V(volprobe8)  V(volprobe4)
# 1203  0.00005           0.0      8.970832      8.992415
# 1204  0.00005           0.0      8.970548      8.992128

# %% [markdown]
# ##Calculo de Corriente del Diodo

# %%
plt.plot(df["time"],(df["V(volprobe4)"]-df["V(volprobe8)"])/0.01, 'g' , linewidth =.50)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
